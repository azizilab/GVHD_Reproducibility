# %% [markdown]
# # GVHD project integrated analysis

# %% [raw]
# Lingting , Xumin, and Pranik
#
# anndata     0.8.0
# scanpy      1.9.1
# -----
# PIL                         9.2.0
# appnope                     0.1.2
# asttokens                   NA
# backcall                    0.2.0
# beta_ufunc                  NA
# binom_ufunc                 NA
# cffi                        1.15.0
# cycler                      0.10.0
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.5.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# entrypoints                 0.4
# executing                   0.8.3
# h5py                        3.7.0
# hypergeom_ufunc             NA
# igraph                      0.9.11
# ipykernel                   6.9.1
# ipython_genutils            0.2.0
# jedi                        0.18.1
# joblib                      1.1.0
# kiwisolver                  1.4.4
# leidenalg                   0.8.10
# llvmlite                    0.38.1
# matplotlib                  3.5.2
# mpl_toolkits                NA
# natsort                     8.1.0
# nbinom_ufunc                NA
# numba                       0.55.2
# numpy                       1.21.0
# packaging                   21.3
# pandas                      1.3.5
# parso                       0.8.3
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# prompt_toolkit              3.0.20
# psutil                      5.9.1
# ptyprocess                  0.7.0
# pure_eval                   0.2.2
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.6.0
# pydevd_concurrency_analyser NA
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.11.2
# pyparsing                   3.0.4
# pytz                        2022.1
# scipy                       1.8.1
# session_info                1.0.0
# setuptools                  63.2.0
# six                         1.16.0
# sklearn                     1.1.1
# stack_data                  0.2.0
# texttable                   1.6.4
# threadpoolctl               3.1.0
# tornado                     6.1
# tqdm                        4.64.0
# traitlets                   5.1.1
# typing_extensions           NA
# wcwidth                     0.2.5
# zmq                         23.2.0
# -----
# IPython             8.4.0
# jupyter_client      7.2.2
# jupyter_core        4.10.0
# notebook            6.4.11
# -----
# Python 3.10.5 | packaged by conda-forge | (main, Jun 14 2022, 07:05:37) [Clang 13.0.1 ]
# macOS-12.3-arm64-arm-64bit
# -----
# Session information updated at 2022-08-14 10:32

# %% [markdown]
#  # verison 2
# absl-py                       1.2.0
# adjustText                    0.7.3
# aiohttp                       3.8.3
# aiosignal                     1.2.0
# alabaster                     0.7.12
# anndata                       0.8.0
# anyio                         3.6.1
# appdirs                       1.4.4
# appnope                       0.1.3
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# asttokens                     2.0.8
# async-timeout                 4.0.2
# attrs                         22.1.0
# Babel                         2.10.3
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# beautifulsoup4                4.11.1
# bioinfokit                    2.0.8
# biopython                     1.79
# bioservices                   1.10.0
# bleach                        5.0.1
# blinker                       1.4
# brotlipy                      0.7.0
# cached-property               1.5.2
# cachetools                    5.2.0
# certifi                       2022.9.24
# cffi                          1.15.1
# charset-normalizer            2.1.0
# chex                          0.1.5
# clang                         14.0
# click                         8.1.3
# colorama                      0.4.5
# colorlog                      6.6.0
# commonmark                    0.9.1
# community                     1.0.0b1
# cryptography                  37.0.4
# cycler                        0.11.0
# dataclasses                   0.8
# debugpy                       1.6.3
# decorator                     5.1.1
# defusedxml                    0.7.1
# Deprecated                    1.2.13
# dm-tree                       0.1.7
# docrep                        0.3.2
# docutils                      0.19
# easydev                       0.12.0
# entrypoints                   0.4
# et-xmlfile                    1.1.0
# etils                         0.8.0
# executing                     0.10.0
# fastjsonschema                2.16.1
# Flask                         2.2.2
# flax                          0.5.2
# flit_core                     3.7.1
# fonttools                     4.36.0
# frozenlist                    1.3.1
# fsspec                        2022.8.2
# future                        0.18.2
# gevent                        21.12.0
# google                        3.0.0
# google-auth                   2.11.0
# google-auth-oauthlib          0.4.6
# graphtools                    1.5.2
# greenlet                      1.1.2
# grequests                     0.6.0
# grpcio                        1.46.4
# gseapy                        0.12.1
# h5py                          3.7.0
# html5lib                      1.1
# hyperopt                      0.1.2
# idna                          3.3
# igraph                        0.9.11
# imageio                       2.21.1
# imagesize                     1.4.1
# importlib-metadata            4.11.4
# importlib-resources           5.9.0
# ipykernel                     6.15.1
# ipython                       8.4.0
# ipython-genutils              0.2.0
# ipywidgets                    8.0.2
# itsdangerous                  2.1.2
# jax                           0.3.17
# jaxlib                        0.3.15
# jedi                          0.18.1
# Jinja2                        3.1.2
# joblib                        1.1.0
# json5                         0.9.5
# jsonschema                    4.9.1
# jupyter-client                7.3.4
# jupyter_core                  4.11.1
# jupyter-server                1.18.1
# jupyterlab                    3.4.5
# jupyterlab-pygments           0.2.2
# jupyterlab-server             2.15.0
# jupyterlab-widgets            3.0.3
# kiwisolver                    1.4.4
# kneed                         0.7.0
# leidenalg                     0.8.10
# llvmlite                      0.38.1
# lxml                          4.9.1
# magic-impute                  3.0.0
# Markdown                      3.4.1
# MarkupSafe                    2.1.1
# matplotlib                    3.5.3
# matplotlib-inline             0.1.6
# matplotlib-venn               0.11.7
# mistune                       0.8.4
# mizani                        0.7.4
# msgpack                       1.0.4
# mudata                        0.2.0
# multidict                     6.0.2
# multipledispatch              0.6.0
# munkres                       1.1.4
# natsort                       8.1.0
# nbclassic                     0.4.3
# nbclient                      0.6.6
# nbconvert                     6.5.3
# nbformat                      5.4.0
# nest-asyncio                  1.5.5
# networkx                      2.8.5
# notebook                      6.4.12
# notebook-shim                 0.1.0
# numba                         0.55.2
# numpy                         1.22.4
# numpyro                       0.10.1
# oauthlib                      3.2.1
# opencv-python                 4.6.0.66
# openpyxl                      3.0.10
# opt-einsum                    3.3.0
# optax                         0.1.3
# packaging                     21.3
# palettable                    3.3.0
# pandas                        1.3.5
# pandocfilters                 1.5.0
# parso                         0.8.3
# patsy                         0.5.2
# pexpect                       4.8.0
# PhenoGraph                    1.5.7
# pickleshare                   0.7.5
# Pillow                        9.2.0
# pip                           22.2.2
# pkgutil_resolve_name          1.3.10
# plotly                        5.10.0
# plotnine                      0.9.0
# prometheus-client             0.14.1
# prompt-toolkit                3.0.30
# protobuf                      3.20.1
# psutil                        5.9.1
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# py-pcha                       0.1.3
# pyasn1                        0.4.8
# pyasn1-modules                0.2.7
# pycparser                     2.21
# pyDeprecate                   0.3.2
# Pygments                      2.13.0
# PyGSP                         0.5.1
# PyJWT                         2.5.0
# pymongo                       4.2.0
# pynndescent                   0.5.7
# pyOpenSSL                     22.0.0
# pyparsing                     3.0.9
# pyro-api                      0.1.2
# pyro-ppl                      1.8.2+2e3bd02
# pyrsistent                    0.18.1
# PySocks                       1.7.1
# python-dateutil               2.8.2
# python-Levenshtein            0.12.2
# python-louvain                0.16
# pytoml                        0.1.21
# pytorch-lightning             1.7.6
# pytz                          2022.2.1
# pyu2f                         0.1.5
# PyWavelets                    1.3.0
# PyYAML                        6.0
# pyzmq                         23.2.1
# requests                      2.28.1
# requests-cache                0.4.13
# requests-oauthlib             1.3.1
# rich                          11.1.0
# rsa                           4.9
# scanpy                        1.9.1
# scikit-dimension              0.3.2
# scikit-image                  0.19.3
# scikit-learn                  1.1.2
# scikit-misc                   0.1.4
# scipy                         1.9.0
# scprep                        1.2.0
# scvi                          0.6.8
# scvi-tools                    0.17.4
# seaborn                       0.11.2
# Send2Trash                    1.8.0
# session-info                  1.0.0
# setuptools                    65.0.2
# six                           1.16.0
# sniffio                       1.2.0
# snowballstemmer               2.2.0
# soupsieve                     2.3.2.post1
# Sphinx                        5.1.1
# sphinxcontrib-applehelp       1.0.2
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.0
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# squarify                      0.4.3
# stack-data                    0.4.0
# statannotations               0.4.4
# statsmodels                   0.13.2
# stdlib-list                   0.7.0
# suds-community                1.1.2
# tabulate                      0.8.10
# tangram-sc                    1.0.3
# tasklogger                    1.2.0
# tenacity                      8.0.1
# tensorboard                   2.10.0
# tensorboard-data-server       0.6.0
# tensorboard-plugin-wit        1.8.1
# terminado                     0.15.0
# texttable                     1.6.4
# textwrap3                     0.9.2
# threadpoolctl                 3.1.0
# tifffile                      2022.8.12
# tinycss2                      1.1.1
# tomli                         2.0.1
# toolz                         0.12.0
# torch                         1.13.0.dev20220925
# torchaudio                    0.13.0.dev20220925
# torchmetrics                  0.9.3
# torchvision                   0.14.0.dev20220925
# tornado                       6.2
# tqdm                          4.64.0
# traitlets                     5.3.0
# typing_extensions             4.3.0
# umap-learn                    0.5.3
# unicodedata2                  14.0.0
# urllib3                       1.26.11
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              1.3.3
# Werkzeug                      2.2.2
# wheel                         0.37.1
# widgetsnbextension            4.0.3
# wrapt                         1.14.1
# xlrd                          1.2.0
# xmltodict                     0.13.0
# yamlordereddictloader         0.4.0
# yarl                          1.7.2
# zipp                          3.8.1
# zope.event                    4.5.0
# zope.interface                5.4.0

# %%
#conda activate scanpy

# %%
#!TMPDIR=/burg//iicd/users/ls3456/GVHD/

# %%
#!pip install scvi

# %%
#!pip install scanpy

# %%
#!pip list

# %%
#!pip install openpyxl
#anndata needs to be 0.8.0
from glob import glob
import numpy as np
import pandas as pd
import scanpy as sc
import anndata as ad
import anndata
import pickle
import matplotlib.pyplot as plt
from tqdm import tqdm
import gc
import tarfile
import seaborn as sns
import scvi
import torch

from collections import OrderedDict
import pickle
#import scrublet as scr
import scipy.io
import matplotlib.pyplot as plt
import os

# %%
#!pip install scvi

# %%
sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
#sc.logging.print_versions()
sc.set_figure_params(dpi=80)

# %% [markdown]
# # Loading data

# %%
#!pip install openpyxl

# %% [raw]
# # You can update your data location in the meta file
# meta_df = pd.read_excel('/burg/iicd/users/ls3456/GVHD/scRNAseq_TCR_samples_meta_LS-13_f.xlsx')
# meta_df.index = meta_df['Sample ID']

# %% [raw]
# meta_df.head()

# %%
# Update the sample list here need to be the same as sample ID
Sample_list = ["R096_Tc17_up","R096_Tc17_low","RH01","RH02","RH03","RH04","RH05","RH06","RH07","RH08","RH09","RH10","RH11","RH12","RH13","RH14","UA01","UA02","UA03","UA04","UA05","UA06","UA07","UA08","UA09","UA10","UA11","UA12",'UA13','UA14','UA15','UA19','UA20','UA21','UA22','UA23','UA24','UA26','UA30','UA31','UA32','UA33','UA34','UA35','UA36','UA37','UA38','UA39','UA40','UA41']
#Sample_list = ["R096_Tc17_up","R096_Tc17_low","RH01","RH02","RH03","RH04"]

# %%
filtered_combined = anndata.read_h5ad('/Users/lingting/Documents/GVHD_project/Paper_ready_pipeline/anndata_file/filtered_combined_all_PatientID_f.h5ad')

# %%
filtered_combined.obs_names_make_unique()

# %%
filtered_combined

# %% [markdown]
# # Stack plots on cell proportion

# %%
from copy import deepcopy

# %%
sorter = ['C155','C101','C162','C157','R085','C160','C159','C152','C068','C98','C66','C179','ND001','ND003']

# %%
sc.pl.umap(filtered_combined, color=['SampleID'], frameon=False)

# %%
sc.pl.umap(filtered_combined, color=['leiden_0.15'], frameon=False)

# %%
# Extract the color list from Tcell_sc_3_7000deg.uns['leiden_0.5_colors']

#new_cluster_names = ['T_cells','Plasma_cells',"Myeloid","Fibroblast","B_cells","NK_cells","Epithelial","Epithelial_2",'Endothelial', "Mast_cells","Fibroblast_2"]
#filtered_combined.rename_categories('leiden_0.15', new_cluster_names)
colors = filtered_combined.uns['leiden_0.15_colors']

# Extract unique cluster labels from Tcell_sc_3_7000deg.obs['leiden_0.5']
unique_clusters = filtered_combined.obs['leiden_0.15'].cat.categories

# Create a mapping from cluster labels to colors
cluster_colors = {cluster: color for cluster, color in zip(unique_clusters, colors)}
print(cluster_colors)

# %%
savepath = '/Users/lingting/Documents/GVHD_project/Paper_ready_pipeline/Figures/single_cell_figures/'
obs_1 = 'SampleID'
obs_2 = 'leiden_0.15'

n_categories = {x : len(filtered_combined.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = filtered_combined.obs[[obs_2, obs_1]].values

obs2_clusters = filtered_combined.obs[obs_2].cat.categories.tolist()
obs1_clusters = filtered_combined.obs[obs_1].cat.categories.tolist()

obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
  obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
  obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]

df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.head()

x = obs1_clusters
plt.figure(figsize=(10, 10))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_2]):
  bot = 0.0
  color = filtered_combined.uns[obs_2 + '_colors'][0]
  for j in range(i):
    bot += df_obs2.iloc[j]
    color = filtered_combined.uns[obs_2 + '_colors'][i]
  plt.bar(x, df_obs2.iloc[i], bottom=bot, color=color, label=obs2_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_1 + '_stacked_barplot_color.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.head()

x = obs2_clusters
plt.figure(figsize=(10, 10))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_1]):
  bot = 0.0
  color = filtered_combined.uns[obs_1 + '_colors'][0]
  for j in range(i):
    bot += df_obs1.iloc[j]
    color = filtered_combined.uns[obs_1 + '_colors'][i]
  plt.bar(x, df_obs1.iloc[i], bottom=bot, color=color,
          label=obs1_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_2 + '_stacked_barplot.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

# %%
sc.pl.umap(filtered_combined, color=['PatientID'], frameon=False)

# %%
#savepath = '/Users/lingtingshi/Documents/Azizi_lab/GVHD/'
obs_1 = 'PatientID'
obs_2 = 'leiden_0.15'

n_categories = {x : len(filtered_combined.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = filtered_combined.obs[[obs_2, obs_1]].values

obs2_clusters = filtered_combined.obs[obs_2].cat.categories.tolist()
obs1_clusters = filtered_combined.obs[obs_1].cat.categories.tolist()

obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
  obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
  obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]



df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.index = obs2_clusters
df_obs2.columns = obs1_clusters
df_obs2 = df_obs2.reindex(columns=sorter)

df_obs2.T.plot(kind="bar", stacked=True)
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')


df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.index = obs1_clusters
df_obs1.columns = obs2_clusters

df_obs1.T.plot(kind="bar", stacked=True)
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')

# %%
#Fresh and frozen
#savepath = '/Users/lingtingshi/Documents/Azizi_lab/GVHD/'
obs_1 = 'PatientID'
obs_2 = 'leiden_0.15'
fresh = filtered_combined[filtered_combined.obs['FreshorFrozen']== 'Fresh']

n_categories = {x : len(fresh.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = fresh.obs[[obs_2, obs_1]].values

obs2_clusters = fresh.obs[obs_2].cat.categories.tolist()
obs1_clusters = fresh.obs[obs_1].cat.categories.tolist()

obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
  obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
  obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]



df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.index = obs2_clusters
df_obs2.columns = obs1_clusters
df_obs2 = df_obs2.reindex(columns=sorter)

df_obs2.T.plot(kind="bar", stacked=True)
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')


df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.index = obs1_clusters
df_obs1.columns = obs2_clusters

df_obs1.T.plot(kind="bar", stacked=True)
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')

# %%
#Fresh and frozen
#savepath = '/Users/lingtingshi/Documents/Azizi_lab/GVHD/'
obs_1 = 'PatientID'
obs_2 = 'leiden_0.15'
frozen = filtered_combined[filtered_combined.obs['FreshorFrozen']== 'Frozen']

n_categories = {x : len(frozen.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = frozen.obs[[obs_2, obs_1]].values

obs2_clusters = frozen.obs[obs_2].cat.categories.tolist()
obs1_clusters = frozen.obs[obs_1].cat.categories.tolist()

obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
  obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
  obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]



df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.index = obs2_clusters
df_obs2.columns = obs1_clusters
df_obs2 = df_obs2.reindex(columns=sorter)

df_obs2.T.plot(kind="bar", stacked=True)
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')


df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.index = obs1_clusters
df_obs1.columns = obs2_clusters

df_obs1.T.plot(kind="bar", stacked=True)
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')

# %%
filtered_combined.obs.columns

# %%
sc.pl.umap(filtered_combined, color=['Tissue_Location'], frameon=False)

# %%
obs_1 = 'Tissue_Location'
obs_2 = 'leiden_0.15'

n_categories = {x : len(filtered_combined.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = filtered_combined.obs[[obs_2, obs_1]].values

obs2_clusters = filtered_combined.obs[obs_2].cat.categories.tolist()
obs1_clusters = filtered_combined.obs[obs_1].cat.categories.tolist()

obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
  obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
  obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]

df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.head()

x = obs1_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_2]):
  bot = 0.0
  color = filtered_combined.uns[obs_2 + '_colors'][0]
  for j in range(i):
    bot += df_obs2.iloc[j]
    color = filtered_combined.uns[obs_2 + '_colors'][i]
  plt.bar(x, df_obs2.iloc[i], bottom=bot, color=color, label=obs2_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_1 + '_stacked_barplot_color.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.head()

x = obs2_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_1]):
  bot = 0.0
  color = filtered_combined.uns[obs_1 + '_colors'][0]
  for j in range(i):
    bot += df_obs1.iloc[j]
    color = filtered_combined.uns[obs_1 + '_colors'][i]
  plt.bar(x, df_obs1.iloc[i], bottom=bot, color=color,
          label=obs1_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_2 + '_stacked_barplot.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

# %%
obs_1 = 'SampleID'
obs_2 = 'leiden_0.15'

n_categories = {x : len(filtered_combined.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = filtered_combined.obs[[obs_2, obs_1]].values

obs2_clusters = filtered_combined.obs[obs_2].cat.categories.tolist()
obs1_clusters = filtered_combined.obs[obs_1].cat.categories.tolist()

obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
  obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
  obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]

df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.head()

x = obs1_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_2]):
  bot = 0.0
  color = filtered_combined.uns[obs_2 + '_colors'][0]
  for j in range(i):
    bot += df_obs2.iloc[j]
    color = filtered_combined.uns[obs_2 + '_colors'][i]
  plt.bar(x, df_obs2.iloc[i], bottom=bot, color=color, label=obs2_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_1 + '_stacked_barplot_color.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.head()

x = obs2_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_1]):
  bot = 0.0
  color = filtered_combined.uns[obs_1 + '_colors'][0]
  for j in range(i):
    bot += df_obs1.iloc[j]
    color = filtered_combined.uns[obs_1 + '_colors'][i]
  plt.bar(x, df_obs1.iloc[i], bottom=bot, color=color,
          label=obs1_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_2 + '_stacked_barplot.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

# %%
sc.pl.umap(filtered_combined, color=['LPorIE'], frameon=False)

# %%
obs_1 = 'LPorIE'
obs_2 = 'leiden_0.15'

n_categories = {x : len(filtered_combined.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = filtered_combined.obs[[obs_2, obs_1]].values

obs2_clusters = filtered_combined.obs[obs_2].cat.categories.tolist()
obs1_clusters = filtered_combined.obs[obs_1].cat.categories.tolist()

obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
  obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
  obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]

df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.head()

x = obs1_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_2]):
  bot = 0.0
  color = filtered_combined.uns[obs_2 + '_colors'][0]
  for j in range(i):
    bot += df_obs2.iloc[j]
    color = filtered_combined.uns[obs_2 + '_colors'][i]
  plt.bar(x, df_obs2.iloc[i], bottom=bot, color=color, label=obs2_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_1 + '_stacked_barplot_color.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.head()

x = obs2_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_1]):
  bot = 0.0
  color = filtered_combined.uns[obs_1 + '_colors'][0]
  for j in range(i):
    bot += df_obs1.iloc[j]
    color = filtered_combined.uns[obs_1 + '_colors'][i]
  plt.bar(x, df_obs1.iloc[i], bottom=bot, color=color,
          label=obs1_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_2 + '_stacked_barplot.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

# %%
filtered_combined.obs['PatientID_Tissue_Location'] = filtered_combined.obs['Tissue_Location'].astype(str)+'_'+filtered_combined.obs['PatientID'].astype(str)

# %%
sc.pl.umap(filtered_combined, color=['PatientID_Tissue_Location'], frameon=False)

# %%
filtered_combined.obs['PatientID_LPorIE'] = filtered_combined.obs['LPorIE'].astype(str)+'_'+filtered_combined.obs['PatientID'].astype(str)
sc.pl.umap(filtered_combined, color=['PatientID_LPorIE'], frameon=False)

# %%
obs_1 = 'PatientID'
obs_2 = 'leiden_0.15'

n_categories = {x : len(filtered_combined.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = filtered_combined.obs[[obs_2, obs_1]].values

obs2_clusters = filtered_combined.obs[obs_2].cat.categories.tolist()
obs1_clusters = filtered_combined.obs[obs_1].cat.categories.tolist()


obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
    obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
    obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]

df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.head()

x = obs1_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_2]):
  bot = 0.0
  color = filtered_combined.uns[obs_2 + '_colors'][0]
  for j in range(i):
    bot += df_obs2.iloc[j]
    color = filtered_combined.uns[obs_2 + '_colors'][i]
  plt.bar(x, df_obs2.iloc[i], bottom=bot, color=color, label=obs2_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_1 + '_stacked_barplot_color.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.head()

x = obs2_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_1]):
  bot = 0.0
  color = filtered_combined.uns[obs_1 + '_colors'][0]
  for j in range(i):
    bot += df_obs1.iloc[j]
    color = filtered_combined.uns[obs_1 + '_colors'][i]
  plt.bar(x, df_obs1.iloc[i], bottom=bot, color=color,
          label=obs1_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_2 + '_stacked_barplot.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

# %%
sc.pl.umap(filtered_combined, color=['GVHD_Grade_1'], frameon=False)

# %%
sc.pl.umap(filtered_combined, color=['leiden_0.15'], frameon=False)

# %%
filtered_combined.obs.loc[filtered_combined.obs['PatientID']=='C179','GVHD_Grade_1'] = "Mild"
filtered_combined.obs.loc[filtered_combined.obs['PatientID']=='R085','GVHD_Grade_1'] = "No"

filtered_combined.obs['GVHD_Grade_1'] = filtered_combined.obs['GVHD_Grade_1'].astype('category')
filtered_combined.obs['GVHD_Grade_1'] = filtered_combined.obs['GVHD_Grade_1'].cat.add_categories(['Treated'])
filtered_combined.obs.loc[filtered_combined.obs['Days_post-Transplant']==444.0,'GVHD_Grade_1'] = "Treated"



filtered_combined.obs['PatientID_Time'] = filtered_combined.obs['PatientID'].astype(str)+'_'+filtered_combined.obs['Days_post-Transplant'].astype(str)

sc.pl.umap(filtered_combined, color=['PatientID_Time'],ncols=2)

# %%
filtered_combined.obs['PatientID_Tissue_Loc'] = filtered_combined.obs['PatientID'].astype(str)+'_'+filtered_combined.obs['Tissue_Location'].astype(str)

filtered_combined.obs['PatientID_Tissue_Loc'] = filtered_combined.obs['PatientID'].astype(str)+'_'+filtered_combined.obs['Tissue_Location'].astype(str)

filtered_combined.obs.loc[filtered_combined.obs['PatientID_Tissue_Loc']=='C162_Upper GI','GVHD_Grade_1'] = "No"
filtered_combined.obs.loc[filtered_combined.obs['PatientID_Time']=='C160_28.0','GVHD_Grade_1'] = "Mild"
filtered_combined.obs.loc[filtered_combined.obs['PatientID_Time']=='C160_196.0','GVHD_Grade_1'] = "No"

filtered_combined.obs['PatientID_Grade'] = filtered_combined.obs['PatientID'].astype(str)+'_'+filtered_combined.obs['GVHD_Grade_1'].astype(str)

sc.pl.umap(filtered_combined, color=['PatientID_Tissue_Loc'],ncols=2)

# %%
filtered_combined.obs['PatientID_grade'] = filtered_combined.obs['PatientID'].astype(str)+'_'+filtered_combined.obs['GVHD_Grade_1'].astype(str)
sc.pl.umap(filtered_combined, color=['PatientID_grade'],ncols=2)

# %%
filtered_combined.obs['SampleID_Grade'] = filtered_combined.obs['SampleID'].astype(str)+'_'+filtered_combined.obs['GVHD_Grade_1'].astype(str)

# %%
sc.pl.umap(filtered_combined, color=['SampleID_Grade'],ncols=2)

# %%
imm_celltype = ['T cells', "Plasma cells","Myeloid",'B cells','NK cells','Mast Cells']
imm_filtered_combined = filtered_combined[filtered_combined.obs['leiden_0.15'].isin(imm_celltype)]

# %%
imm_filtered_combined.obs['SampleID_Grade'] = imm_filtered_combined.obs['SampleID_Grade'].astype('category')
imm_filtered_combined.obs['leiden_0.15'] = imm_filtered_combined.obs['leiden_0.15'].astype('category')

# %%
filtered_combined.obs['leiden_0.15']

# %%
obs_1 = 'PatientID'
obs_2 = 'leiden_0.15'

n_categories = {x : len(filtered_combined.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = filtered_combined.obs[[obs_2, obs_1]].values

obs2_clusters = filtered_combined.obs[obs_2].cat.categories.tolist()
obs1_clusters = filtered_combined.obs[obs_1].cat.categories.tolist()


obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
    obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
    obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]

df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.head()

x = obs1_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_2]):
  bot = 0.0
  color = filtered_combined.uns[obs_2 + '_colors'][0]
  for j in range(i):
    bot += df_obs2.iloc[j]
    color = filtered_combined.uns[obs_2 + '_colors'][i]
  plt.bar(x, df_obs2.iloc[i], bottom=bot, color=color, label=obs2_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_1 + '_stacked_barplot_color.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.head()

x = obs2_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_1]):
  bot = 0.0
  color = filtered_combined.uns[obs_1 + '_colors'][0]
  for j in range(i):
    bot += df_obs1.iloc[j]
    color = filtered_combined.uns[obs_1 + '_colors'][i]
  plt.bar(x, df_obs1.iloc[i], bottom=bot, color=color,
          label=obs1_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_2 + '_stacked_barplot.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

# %%
sc.pl.umap(imm_filtered_combined, color=['leiden_0.15'])

# %% [markdown]
# # Figure 4B

# %%
import matplotlib as mpl
# Update your existing rcParams
mpl.rcParams.update({
    'font.size': 8,
    'svg.fonttype': 'none',
    'font.family': 'Arial',
    'figure.figsize': (2.5, 2.5)  # Set default figure size to 6×4 inches
})
mpl.rcParams['axes.titlesize'] = 8
mpl.rcParams['xtick.labelsize'] = 8  # Colorbar tick label size 
mpl.rcParams['ytick.labelsize'] = 8  # Colorbar tick label size

# %%
sorter_grade = ['ND','No','Mild','Severe']

obs_1 = 'GVHD_Grade_1'
obs_2 = 'leiden_0.15'

n_categories = {x : len(imm_filtered_combined.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = imm_filtered_combined.obs[[obs_2, obs_1]].values

obs2_clusters = imm_filtered_combined.obs[obs_2].cat.categories.tolist()
obs1_clusters = imm_filtered_combined.obs[obs_1].cat.categories.tolist()

obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
  obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
  obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]



df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.index = obs2_clusters
df_obs2.columns = obs1_clusters
df_obs2 = df_obs2.reindex(columns=sorter_grade)

df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.index = obs1_clusters
df_obs1.columns = obs2_clusters


# For the first plot using df_obs2
leiden_colors = imm_filtered_combined.uns['leiden_0.15_colors']
df_obs2 = df_obs2.reindex(columns=sorter_grade)
ax = df_obs2.T.plot(kind="bar", 
                    stacked=True, 
                    color=leiden_colors,  # Use the leiden colors
                    figsize=(3.5,2.5))
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left',frameon = False)
plt.grid(False)
plt.tight_layout()
plt.savefig('/Users/lingting/Documents/GVHD_project/Paper_ready_pipeline/Figures/single_cell_figures/immune_cell_type_bar_plot.png', 
            dpi=300, 
            bbox_inches='tight', transparent = True)
plt.savefig('/Users/lingting/Documents/GVHD_project/Paper_ready_pipeline/Figures/single_cell_figures/immune_cell_type_bar_plot.pdf', 
            dpi=300, 
            bbox_inches='tight', transparent = True)
plt.savefig('/Users/lingting/Documents/GVHD_project/Paper_ready_pipeline/Figures/single_cell_figures/immune_cell_type_bar_plot.svg', 
            dpi=300, 
            bbox_inches='tight', transparent = True)
plt.show()

# For the second plot using df_obs1
ax = df_obs1.T.plot(kind="bar", 
                    stacked=True, 
                    color=leiden_colors,  # Use the leiden colors
                    figsize=(3, 2.5))
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left',frameon = False)
plt.grid(False)
plt.tight_layout()
plt.savefig('/Users/lingting/Documents/GVHD_project/Paper_ready_pipeline/Figures/single_cell_figures/immune_cell_type_bar_plot_2.png', 
            dpi=300, 
            bbox_inches='tight')
plt.savefig('/Users/lingting/Documents/GVHD_project/Paper_ready_pipeline/Figures/single_cell_figures/immune_cell_type_bar_plot_2.pdf', 
            dpi=300, 
            bbox_inches='tight')
plt.show()

# %%
from matplotlib import rcParams
import seaborn as sns
import matplotlib.pyplot as plt
from statannotations.Annotator import Annotator  # Assuming you use statannotations for the p-values

# Assuming adata is already defined and contains the necessary data
obs_1 = 'SampleID_Grade'
obs_2 = 'leiden_0.15'
num = 1

for adata in [imm_filtered_combined]:
    n_categories = {x: len(adata.obs[x].cat.categories) for x in [obs_1, obs_2]}
    df = adata.obs[[obs_2, obs_1]].values

    obs2_clusters = adata.obs[obs_2].cat.categories.tolist()
    obs1_clusters = adata.obs[obs_1].cat.categories.tolist()

    obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                    for k in obs1_clusters}
    obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                    for k in obs2_clusters}
    for b, l in df:
        obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
        obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1
    obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
    obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))
    for i, k in enumerate(obs2_clusters):
        obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
    for i, k in enumerate(obs1_clusters):
        obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

    sums = np.sum(obs2_to_obs1_array, 0)
    for col in range(np.size(obs2_to_obs1_array, 1)):
        for row in range(np.size(obs2_to_obs1_array, 0)):
            obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

    sums2 = np.sum(obs1_to_obs2_array, 0)
    for col in range(np.size(obs1_to_obs2_array, 1)):
        for row in range(np.size(obs1_to_obs2_array, 0)):
            obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]

    df_obs2 = pd.DataFrame(obs2_to_obs1_array)
    df_obs2.index = obs2_clusters
    df_obs2.columns = obs1_clusters

    # Sort columns if necessary
    sorter = sorted(obs1_clusters)
    df_obs2 = df_obs2.reindex(columns=sorter)

    df_obs2.T.plot(kind="bar", stacked=True, color=adata.uns[obs_2 + '_colors'])
    plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
    plt.show()

    df_obs1 = pd.DataFrame(obs1_to_obs2_array)
    df_obs1.index = obs1_clusters
    df_obs1.columns = obs2_clusters
    df_obs1.T.plot(kind="bar", stacked=True, color=adata.uns[obs_1 + '_colors'])
    plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
    plt.show()

    print(num)
    num += 1
    p_list = []

    for i in adata.obs['leiden_0.15'].unique():
        substring = 'Severe'
        column_mask = df_obs2.columns.str.contains(substring)
        selected_columns_severe = df_obs2.loc[:, column_mask]
        severe = selected_columns_severe.loc[i].values[~np.isnan(selected_columns_severe.loc[i].values)]

        substring = 'Mild'
        column_mask = df_obs2.columns.str.contains(substring)
        selected_columns_mild = df_obs2.loc[:, column_mask]
        mild = selected_columns_mild.loc[i].values[~np.isnan(selected_columns_mild.loc[i].values)]

        substring = 'No'
        column_mask = df_obs2.columns.str.contains(substring)
        selected_columns_no = df_obs2.loc[:, column_mask]
        no = selected_columns_no.loc[i].values[~np.isnan(selected_columns_no.loc[i].values)]

        substring = 'Treated'
        column_mask = df_obs2.columns.str.contains(substring)
        selected_columns_treated = df_obs2.loc[:, column_mask]
        treated = selected_columns_treated.loc[i].values[~np.isnan(selected_columns_treated.loc[i].values)]


        substring = 'ND'
        column_mask = df_obs2.columns.str.contains(substring)
        selected_columns_nd = df_obs2.loc[:, column_mask]
        nd = selected_columns_nd.loc[i].values[~np.isnan(selected_columns_nd.loc[i].values)]

        
        df_severe = pd.DataFrame()
        df_severe['Value'] = severe
        df_severe['Grade'] = 'severe'

        df_mild = pd.DataFrame()
        df_mild['Value'] = mild
        df_mild['Grade'] = 'mild'

        df_no = pd.DataFrame()
        df_no['Value'] = no
        df_no['Grade'] = 'no'

        df_treated = pd.DataFrame()
        df_treated['Value'] = treated
        df_treated['Grade'] = 'no'

        df_ND = pd.DataFrame()
        df_ND['Value'] = nd
        df_ND['Grade'] = 'no'
        

        palette = {'no': '#09BB8C', 'mild': '#005A8F', 'severe': '#B85000'}

        result = pd.concat([df_no, df_treated, df_ND,df_mild, df_severe])
        rcParams.update({'font.size': 14})
        fig, ax = plt.subplots(figsize=(5, 3), dpi=300)
        sns.boxplot(x='Grade', y='Value', data=result, ax=ax, palette=palette, order=['no', 'mild', 'severe'])
        sns.stripplot(x='Grade', y='Value', data=result, ax=ax, color='black', alpha=0.5, jitter=True, order=['no', 'mild', 'severe'])

        ax.spines[['right', 'top']].set_visible(False)
        ax.set_xlabel('')
        ax.set_ylabel('Cell type proportion')
        ax.set_title(i)
        ax.get_xaxis().tick_bottom()
        ax.get_yaxis().tick_left()

        pairs = [('no', 'mild'), ('mild', 'severe'), ('no', 'severe')]
        annotator = Annotator(ax, pairs, data=result, x='Grade', y='Value')
        annotator.configure(test='Kruskal')
        annotator.apply_and_annotate()
        plt.tight_layout()

        # Save figure with 300 DPI
        plt.savefig(f'/Users/lingting/Documents/GVHD_project/Paper_ready_pipeline/Figures/single_cell_figures//fig_{i}_boxplot_300dpi.png', dpi=300)
        plt.savefig(f'/Users/lingting/Documents/GVHD_project/Paper_ready_pipeline/Figures/single_cell_figures//fig_{i}_boxplot_300dpi.pdf', dpi=300)

        plt.show()

# %%
obs_1 = 'Tissue_Location'
obs_2 = 'leiden_0.15'


n_categories = {x : len(imm_filtered_combined.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = imm_filtered_combined.obs[[obs_2, obs_1]].values

obs2_clusters = imm_filtered_combined.obs[obs_2].cat.categories.tolist()
obs1_clusters = imm_filtered_combined.obs[obs_1].cat.categories.tolist()


obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
    obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
    obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]

df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.head()

x = obs1_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_2]):
  bot = 0.0
  color = imm_filtered_combined.uns[obs_2 + '_colors'][0]
  for j in range(i):
    bot += df_obs2.iloc[j]
    color = imm_filtered_combined.uns[obs_2 + '_colors'][i]
  plt.bar(x, df_obs2.iloc[i], bottom=bot, color=color, label=obs2_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_1 + '_stacked_barplot_color.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.head()

x = obs2_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_1]):
  bot = 0.0
  color = imm_filtered_combined.uns[obs_1 + '_colors'][0]
  for j in range(i):
    bot += df_obs1.iloc[j]
    color = imm_filtered_combined.uns[obs_1 + '_colors'][i]
  plt.bar(x, df_obs1.iloc[i], bottom=bot, color=color,
          label=obs1_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_2 + '_stacked_barplot.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

# %%
sc.pl.umap(imm_filtered_combined, color=['GVHD_Grade_1','PatientID'],ncols=2)

# %%
obs_1 = 'GVHD_Grade_1'
obs_2 = 'leiden_0.15'

n_categories = {x : len(imm_filtered_combined.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = imm_filtered_combined.obs[[obs_2, obs_1]].values

obs2_clusters = imm_filtered_combined.obs[obs_2].cat.categories.tolist()
obs1_clusters = imm_filtered_combined.obs[obs_1].cat.categories.tolist()


obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
    obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
    obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]

df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.head()

x = obs1_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_2]):
  bot = 0.0
  color = imm_filtered_combined.uns[obs_2 + '_colors'][0]
  for j in range(i):
    bot += df_obs2.iloc[j]
    color = imm_filtered_combined.uns[obs_2 + '_colors'][i]
  plt.bar(x, df_obs2.iloc[i], bottom=bot, color=color, label=obs2_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_1 + '_stacked_barplot_color.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.head()

x = obs2_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_1]):
  bot = 0.0
  color = imm_filtered_combined.uns[obs_1 + '_colors'][0]
  for j in range(i):
    bot += df_obs1.iloc[j]
    color = imm_filtered_combined.uns[obs_1 + '_colors'][i]
  plt.bar(x, df_obs1.iloc[i], bottom=bot, color=color,
          label=obs1_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_2 + '_stacked_barplot.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

# %%
imm_filtered_combined.obs['PatientID']

# %%
sorter=['C155',
 'C101',
 'C162',
 'C157',
 'R085',
 'C160',
'C86',
 'C159',
 'C152',
 'C068',
 'C98',
 'C66',
 'C179',
 'ND001',
 'ND003']
obs_1 = 'PatientID'
obs_2 = 'leiden_0.15'

n_categories = {x : len(imm_filtered_combined.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = imm_filtered_combined.obs[[obs_2, obs_1]].values

obs2_clusters = imm_filtered_combined.obs[obs_2].cat.categories.tolist()
obs1_clusters = imm_filtered_combined.obs[obs_1].cat.categories.tolist()

obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
    obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
    obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
    obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
    obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
    for row in range(np.size(obs2_to_obs1_array, 0)):
        obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
    for row in range(np.size(obs1_to_obs2_array, 0)):
        obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]



df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.index = obs2_clusters
df_obs2.columns = obs1_clusters
df_obs2 = df_obs2.reindex(columns=sorter)

df_obs2.T.plot(kind="bar", stacked=True)
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')


df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.index = obs1_clusters
df_obs1.columns = obs2_clusters

df_obs1.T.plot(kind="bar", stacked=True)
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')

# %%
#Fresh and frozen
#savepath = '/Users/lingtingshi/Documents/Azizi_lab/GVHD/'
obs_1 = 'PatientID'
obs_2 = 'leiden_0.15'
fresh = imm_filtered_combined[imm_filtered_combined.obs['FreshorFrozen']== 'Fresh']

n_categories = {x : len(fresh.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = fresh.obs[[obs_2, obs_1]].values

obs2_clusters = fresh.obs[obs_2].cat.categories.tolist()
obs1_clusters = fresh.obs[obs_1].cat.categories.tolist()

obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
  obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
  obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]



df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.index = obs2_clusters
df_obs2.columns = obs1_clusters
df_obs2 = df_obs2.reindex(columns=sorter)

df_obs2 = df_obs2.reindex(columns=sorter)
df_obs2.T.plot(kind="bar", stacked=True)
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.title("Fresh")

df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.index = obs1_clusters
df_obs1.columns = obs2_clusters

df_obs1.T.plot(kind="bar", stacked=True)
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.title("Fresh")

# %%
frozen.obs['PatientID']

# %%
#Fresh and frozen
#savepath = '/Users/lingtingshi/Documents/Azizi_lab/GVHD/'
obs_1 = 'PatientID'
obs_2 = 'leiden_0.15'
frozen = imm_filtered_combined[imm_filtered_combined.obs['FreshorFrozen']== 'Frozen']

n_categories = {x : len(frozen.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = frozen.obs[[obs_2, obs_1]].values

obs2_clusters = frozen.obs[obs_2].cat.categories.tolist()
obs1_clusters = frozen.obs[obs_1].cat.categories.tolist()

obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
  obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
  obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]


df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.index = obs2_clusters
df_obs2.columns = obs1_clusters
df_obs2 = df_obs2.reindex(columns=sorter)

df_obs2 = df_obs2[['C155','C101', 'C160','R085','C157','C162','C159','C152','C179','C86','C66','C98','C068','ND001','ND003']]
df_obs2.T.plot(kind="bar", stacked=True)
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.title("Frozen")

df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.index = obs1_clusters
df_obs1.columns = obs2_clusters

df_obs1.T.plot(kind="bar", stacked=True)
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.title("Frozen")

#df_obs2

#df_obs2 = df_obs2[['C155','C101', 'C160','C157', 'R085','C159','C152','C159','C152','C179','C66','C98','C068','ND001','ND003']]

# %%
imm_filtered_combined.obs.columns

# %%
imm_filtered_combined.obs['PatientID_Grade'] =imm_filtered_combined.obs['GVHD_Grade_1'].astype(str) +'_'+imm_filtered_combined.obs['PatientID'].astype(str)

sc.pl.umap(imm_filtered_combined, color=['PatientID_Grade'])

# %%
#Fresh and frozen
#savepath = '/Users/lingtingshi/Documents/Azizi_lab/GVHD/'
obs_1 = 'PatientID_Grade'
obs_2 = 'leiden_0.15'
frozen = imm_filtered_combined[imm_filtered_combined.obs['FreshorFrozen']== 'Frozen']

n_categories = {x : len(frozen.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = frozen.obs[[obs_2, obs_1]].values

obs2_clusters = frozen.obs[obs_2].cat.categories.tolist()
obs1_clusters = frozen.obs[obs_1].cat.categories.tolist()

obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
  obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
  obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]


df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.index = obs2_clusters
df_obs2.columns = obs1_clusters
#df_obs2 = df_obs2.reindex(columns=sorter)


#df_obs2 = df_obs2[['C155_No','C101', 'C160','R085','C157','C162','C159','C152','C179','C66','C98','C068','ND001','ND003']]
df_obs2.T.plot(kind="bar", stacked=True)
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.title("Frozen")

df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.index = obs1_clusters
df_obs1.columns = obs2_clusters

df_obs1.T.plot(kind="bar", stacked=True)
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.title("Frozen")

# %%
from copy import deepcopy
import scipy.stats as stats
obs_1 = 'PatientID_Grade'
obs_2 = 'leiden_0.15'
num = 1

for adata in [frozen]:
    n_categories = {x : len(adata.obs[x].cat.categories) for x in [obs_1, obs_2]}
    df = adata.obs[[obs_2, obs_1]].values

    obs2_clusters = adata.obs[obs_2].cat.categories.tolist()
    obs1_clusters = adata.obs[obs_1].cat.categories.tolist()

    obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
    obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}
    for b, l in df:
        obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
        obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1
    obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
    obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))
    for i, k in enumerate(obs2_clusters):
        obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
    for i, k in enumerate(obs1_clusters):
        obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])
        
    sums = np.sum(obs2_to_obs1_array, 0)
    for col in range(np.size(obs2_to_obs1_array, 1)):
        for row in range(np.size(obs2_to_obs1_array, 0)):
            obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]
            
    sums2 = np.sum(obs1_to_obs2_array, 0)
    for col in range(np.size(obs1_to_obs2_array, 1)):
        for row in range(np.size(obs1_to_obs2_array, 0)):
            obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]
            
    df_obs2 = pd.DataFrame(obs2_to_obs1_array)
    df_obs2.index = obs2_clusters
    df_obs2.columns = obs1_clusters
    #df_obs2 = df_obs2.reindex(columns=ptcy_sorter)
    df_obs2.T.plot(kind="bar", stacked=True, color=adata.uns[obs_2 + '_colors'])
    plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
    plt.show()
    #plt.title(adata)
    df_obs1 = pd.DataFrame(obs1_to_obs2_array)
    df_obs1.index = obs1_clusters
    df_obs1.columns = obs2_clusters
    df_obs1.T.plot(kind="bar", stacked=True,color=adata.uns[obs_1 + '_colors'])
    plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
    plt.show()

    print(num)
    num = num +1

    for i in adata.obs['leiden_0.15'].unique():
        substring = 'Severe'
        column_mask = df_obs2.columns.str.contains(substring)
        # Use the mask to select the desired columns
        selected_columns_severe = df_obs2.loc[:, column_mask]
        severe = selected_columns_severe.loc[i].values[~np.isnan(selected_columns_severe.loc[i].values)]
        substring = 'Mild'
        column_mask = df_obs2.columns.str.contains(substring)
        # Use the mask to select the desired columns
        selected_columns_mild = df_obs2.loc[:, column_mask]
        mild = selected_columns_mild.loc[i].values[~np.isnan(selected_columns_mild.loc[i].values)]
        print(mild)
        print(severe)
        t_stat, p_value = stats.ttest_ind(severe, mild)
        
        print(i)
        print(p_value)
        
        if p_value<=0.05:
            plt.boxplot([mild, severe], labels=['Severe', 'Mild'])

        # Add labels and title
            plt.ylabel('Cell type Proportion')
            plt.title(i)
            plt.show()

# %%
#Fresh and frozen
#savepath = '/Users/lingtingshi/Documents/Azizi_lab/GVHD/'
sorter_c66 = ['Severe_C66','Treated_C66']
obs_1 = 'PatientID_Grade'
obs_2 = 'leiden_0.15'
frozen = imm_filtered_combined[imm_filtered_combined.obs['FreshorFrozen']== 'Frozen']
frozen = frozen[frozen.obs['PatientID']=='C66']

n_categories = {x : len(frozen.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = frozen.obs[[obs_2, obs_1]].values

obs2_clusters = frozen.obs[obs_2].cat.categories.tolist()
obs1_clusters = frozen.obs[obs_1].cat.categories.tolist()

obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
  obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
  obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]


df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.index = obs2_clusters
df_obs2.columns = obs1_clusters
df_obs2 = df_obs2.reindex(columns=sorter_c66)


#df_obs2 = df_obs2[['C155_No','C101', 'C160','R085','C157','C162','C159','C152','C179','C66','C98','C068','ND001','ND003']]
df_obs2.T.plot(kind="bar", stacked=True)
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.title("Frozen")

df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.index = obs1_clusters
df_obs1.columns = obs2_clusters

df_obs1.T.plot(kind="bar", stacked=True)
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.title("Frozen")

# %%
#Fresh and frozen
#savepath = '/Users/lingtingshi/Documents/Azizi_lab/GVHD/'
obs_1 = 'PatientID_Grade'
obs_2 = 'leiden_0.15'
fresh = imm_filtered_combined[imm_filtered_combined.obs['FreshorFrozen']== 'Fresh']
fresh = fresh[fresh.obs['PatientID']!= "R096"]

n_categories = {x : len(fresh.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = fresh.obs[[obs_2, obs_1]].values

obs2_clusters = fresh.obs[obs_2].cat.categories.tolist()
obs1_clusters = fresh.obs[obs_1].cat.categories.tolist()

obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
  obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
  obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]



df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.index = obs2_clusters
df_obs2.columns = obs1_clusters
#df_obs2 = df_obs2.reindex(columns=sorter)

#df_obs2 = df_obs2[['C155','C101', 'C160','C162','R085','C157','C152','C159','C179','C66','C98','C068','ND001','ND003']]
df_obs2.T.plot(kind="bar", stacked=True)
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.title("Fresh")

df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.index = obs1_clusters
df_obs1.columns = obs2_clusters

df_obs1.T.plot(kind="bar", stacked=True)
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.title("Fresh")

# %%
from copy import deepcopy
obs_1 = 'Tissue_Location'
obs_2 = 'leiden_0.15'
num = 1

for adata in [imm_filtered_combined[imm_filtered_combined.obs['PatientID'].isin(['C66','C98','C152','C157','C159','C160','C162','C179'])]]:
    n_categories = {x : len(adata.obs[x].cat.categories) for x in [obs_1, obs_2]}
    df = adata.obs[[obs_2, obs_1]].values

    obs2_clusters = adata.obs[obs_2].cat.categories.tolist()
    obs1_clusters = adata.obs[obs_1].cat.categories.tolist()

    obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
    obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}
    for b, l in df:
        obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
        obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1
    obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
    obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))
    for i, k in enumerate(obs2_clusters):
        obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
    for i, k in enumerate(obs1_clusters):
        obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])
        
    sums = np.sum(obs2_to_obs1_array, 0)
    for col in range(np.size(obs2_to_obs1_array, 1)):
        for row in range(np.size(obs2_to_obs1_array, 0)):
            obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]
            
    sums2 = np.sum(obs1_to_obs2_array, 0)
    for col in range(np.size(obs1_to_obs2_array, 1)):
        for row in range(np.size(obs1_to_obs2_array, 0)):
            obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]
            
    df_obs2 = pd.DataFrame(obs2_to_obs1_array)
    df_obs2.index = obs2_clusters
    df_obs2.columns = obs1_clusters
    #df_obs2 = df_obs2.reindex(columns=ptcy_sorter)
    df_obs2.T.plot(kind="bar", stacked=True, color=filtered_combined.uns[obs_2 + '_colors'])
    plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
    plt.show()
    #plt.title(adata)
    df_obs1 = pd.DataFrame(obs1_to_obs2_array)
    df_obs1.index = obs1_clusters
    df_obs1.columns = obs2_clusters
    df_obs1.T.plot(kind="bar", stacked=True,color=filtered_combined.uns[obs_1 + '_colors'])
    plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
    plt.show()

# %%
from copy import deepcopy
obs_1 = 'PatientID_Tissue_Location'
obs_2 = 'leiden_0.15'
num = 1

for adata in [imm_filtered_combined[imm_filtered_combined.obs['PatientID'].isin(['C66','C98','C152','C157','C159','C160','C162','C179'])]]:
    n_categories = {x : len(adata.obs[x].cat.categories) for x in [obs_1, obs_2]}
    df = adata.obs[[obs_2, obs_1]].values

    obs2_clusters = adata.obs[obs_2].cat.categories.tolist()
    obs1_clusters = adata.obs[obs_1].cat.categories.tolist()

    obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
    obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}
    for b, l in df:
        obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
        obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1
    obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
    obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))
    for i, k in enumerate(obs2_clusters):
        obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
    for i, k in enumerate(obs1_clusters):
        obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])
        
    sums = np.sum(obs2_to_obs1_array, 0)
    for col in range(np.size(obs2_to_obs1_array, 1)):
        for row in range(np.size(obs2_to_obs1_array, 0)):
            obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]
            
    sums2 = np.sum(obs1_to_obs2_array, 0)
    for col in range(np.size(obs1_to_obs2_array, 1)):
        for row in range(np.size(obs1_to_obs2_array, 0)):
            obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]
            
    df_obs2 = pd.DataFrame(obs2_to_obs1_array)
    df_obs2.index = obs2_clusters
    df_obs2.columns = obs1_clusters
    #df_obs2 = df_obs2.reindex(columns=ptcy_sorter)
    df_obs2.T.plot(kind="bar", stacked=True, color=filtered_combined.uns[obs_2 + '_colors'])
    plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
    plt.show()
    #plt.title(adata)
    df_obs1 = pd.DataFrame(obs1_to_obs2_array)
    df_obs1.index = obs1_clusters
    df_obs1.columns = obs2_clusters
    df_obs1.T.plot(kind="bar", stacked=True,color=filtered_combined.uns[obs_1 + '_colors'])
    plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
    plt.show()

    print(num)
    num = num +1

    for i in adata.obs['leiden_0.15'].unique():
        substring = 'Lower'
        column_mask = df_obs2.columns.str.contains(substring)
        # Use the mask to select the desired columns
        selected_columns_severe = df_obs2.loc[:, column_mask]
        severe = selected_columns_severe.loc[i].values[~np.isnan(selected_columns_severe.loc[i].values)]
        substring = 'Upper'
        column_mask = df_obs2.columns.str.contains(substring)
        # Use the mask to select the desired columns
        selected_columns_mild = df_obs2.loc[:, column_mask]
        mild = selected_columns_mild.loc[i].values[~np.isnan(selected_columns_mild.loc[i].values)]
        t_stat, p_value = stats.ttest_rel(severe, mild)
        print(i)
        print(p_value)
        
        if p_value<=0.05:
            plt.boxplot([mild, severe], labels=['Lower', 'Upper'])

        # Add labels and title
            plt.ylabel('Cell type Proportion')
            plt.title(i)
            plt.show()

# %%
from copy import deepcopy
obs_1 = 'PatientID_LPorIE'
obs_2 = 'leiden_0.15'
num = 1

for adata in [imm_filtered_combined, imm_filtered_combined[imm_filtered_combined.obs['Tissue_Location']=="Upper GI"], imm_filtered_combined[imm_filtered_combined.obs['Tissue_Location']=="Lower GI"]]:
    n_categories = {x : len(adata.obs[x].cat.categories) for x in [obs_1, obs_2]}
    df = adata.obs[[obs_2, obs_1]].values

    obs2_clusters = adata.obs[obs_2].cat.categories.tolist()
    obs1_clusters = adata.obs[obs_1].cat.categories.tolist()

    obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
    obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}
    for b, l in df:
        obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
        obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1
    obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
    obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))
    for i, k in enumerate(obs2_clusters):
        obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
    for i, k in enumerate(obs1_clusters):
        obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])
        
    sums = np.sum(obs2_to_obs1_array, 0)
    for col in range(np.size(obs2_to_obs1_array, 1)):
        for row in range(np.size(obs2_to_obs1_array, 0)):
            obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]
            
    sums2 = np.sum(obs1_to_obs2_array, 0)
    for col in range(np.size(obs1_to_obs2_array, 1)):
        for row in range(np.size(obs1_to_obs2_array, 0)):
            obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]
            
    df_obs2 = pd.DataFrame(obs2_to_obs1_array)
    df_obs2.index = obs2_clusters
    df_obs2.columns = obs1_clusters
    #df_obs2 = df_obs2.reindex(columns=ptcy_sorter)
    df_obs2.T.plot(kind="bar", stacked=True, color=filtered_combined.uns[obs_2 + '_colors'])
    plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
    plt.show()
    #plt.title(adata)
    df_obs1 = pd.DataFrame(obs1_to_obs2_array)
    df_obs1.index = obs1_clusters
    df_obs1.columns = obs2_clusters
    df_obs1.T.plot(kind="bar", stacked=True,color=filtered_combined.uns[obs_1 + '_colors'])
    plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
    plt.show()

    print(num)
    num = num +1

    for i in adata.obs['leiden_0.15'].unique():
        substring = 'Intraepithelial Cells'
        column_mask = df_obs2.columns.str.contains(substring)
        # Use the mask to select the desired columns
        selected_columns_severe = df_obs2.loc[:, column_mask]
        severe = selected_columns_severe.loc[i].values[~np.isnan(selected_columns_severe.loc[i].values)]
        substring = 'Lamina Propria Cells'
        column_mask = df_obs2.columns.str.contains(substring)
        # Use the mask to select the desired columns
        selected_columns_mild = df_obs2.loc[:, column_mask]
        mild = selected_columns_mild.loc[i].values[~np.isnan(selected_columns_mild.loc[i].values)]
        t_stat, p_value = stats.ttest_ind(severe, mild)
        print(i)
        print(p_value)
        
        
        if p_value<=0.05:
            plt.boxplot([mild, severe], labels=['Lower', 'Upper'])

        # Add labels and title
            plt.ylabel('Cell type Proportion')
            plt.title(i)
            plt.show()

# %%
sc.pl.umap(imm_filtered_combined, color=['FreshorFrozen'])

# %%
# get rid of healthy patients
healthy_patient = ["ND001","ND003"]
Disease_filtered_combined = imm_filtered_combined[~imm_filtered_combined.obs['PatientID'].isin(healthy_patient)]
healthy_filtered_combined = imm_filtered_combined[imm_filtered_combined.obs['PatientID'].isin(healthy_patient)]

obs_1 = 'FreshorFrozen'
obs_2 = 'leiden_0.15'


n_categories = {x : len(Disease_filtered_combined.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = Disease_filtered_combined.obs[[obs_2, obs_1]].values

obs2_clusters = Disease_filtered_combined.obs[obs_2].cat.categories.tolist()
obs1_clusters = Disease_filtered_combined.obs[obs_1].cat.categories.tolist()

obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
  obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
  obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]

df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.head()

x = obs1_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_2]):
  bot = 0.0
  color = Disease_filtered_combined.uns[obs_2 + '_colors'][0]
  for j in range(i):
    bot += df_obs2.iloc[j]
    color = Disease_filtered_combined.uns[obs_2 + '_colors'][i]
  plt.bar(x, df_obs2.iloc[i], bottom=bot, color=color, label=obs2_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_1 + '_stacked_barplot_color.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.head()

x = obs2_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_1]):
  bot = 0.0
  color = Disease_filtered_combined.uns[obs_1 + '_colors'][0]
  for j in range(i):
    bot += df_obs1.iloc[j]
    color = Disease_filtered_combined.uns[obs_1 + '_colors'][i]
  plt.bar(x, df_obs1.iloc[i], bottom=bot, color=color,
          label=obs1_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_2 + '_stacked_barplot.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

# %%
# get rid of healthy patients
healthy_patient = ["ND001","ND003"]
Disease_filtered_combined = imm_filtered_combined[~imm_filtered_combined.obs['PatientID'].isin(healthy_patient)]
healthy_filtered_combined = imm_filtered_combined[imm_filtered_combined.obs['PatientID'].isin(healthy_patient)]

obs_1 = 'Tissue_Location'
obs_2 = 'leiden_0.15'

Disease_filtered_combined = Disease_filtered_combined[Disease_filtered_combined.obs['FreshorFrozen']== 'Fresh']

n_categories = {x : len(Disease_filtered_combined.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = Disease_filtered_combined.obs[[obs_2, obs_1]].values

obs2_clusters = Disease_filtered_combined.obs[obs_2].cat.categories.tolist()
obs1_clusters = Disease_filtered_combined.obs[obs_1].cat.categories.tolist()

obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
  obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
  obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]

df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.head()

x = obs1_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_2]):
  bot = 0.0
  color = Disease_filtered_combined.uns[obs_2 + '_colors'][0]
  for j in range(i):
    bot += df_obs2.iloc[j]
    color = Disease_filtered_combined.uns[obs_2 + '_colors'][i]
  plt.bar(x, df_obs2.iloc[i], bottom=bot, color=color, label=obs2_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_1 + '_stacked_barplot_color.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.head()

x = obs2_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_1]):
  bot = 0.0
  color = Disease_filtered_combined.uns[obs_1 + '_colors'][0]
  for j in range(i):
    bot += df_obs1.iloc[j]
    color = Disease_filtered_combined.uns[obs_1 + '_colors'][i]
  plt.bar(x, df_obs1.iloc[i], bottom=bot, color=color,
          label=obs1_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_2 + '_stacked_barplot.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

# %%
# get rid of healthy patients
healthy_patient = ["ND001","ND003"]
Disease_filtered_combined = imm_filtered_combined[~imm_filtered_combined.obs['PatientID'].isin(healthy_patient)]
healthy_filtered_combined = imm_filtered_combined[imm_filtered_combined.obs['PatientID'].isin(healthy_patient)]

obs_1 = 'Tissue_Location'
obs_2 = 'leiden_0.15'

Disease_filtered_combined = Disease_filtered_combined[Disease_filtered_combined.obs['FreshorFrozen']== 'Frozen']

n_categories = {x : len(Disease_filtered_combined.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = Disease_filtered_combined.obs[[obs_2, obs_1]].values

obs2_clusters = Disease_filtered_combined.obs[obs_2].cat.categories.tolist()
obs1_clusters = Disease_filtered_combined.obs[obs_1].cat.categories.tolist()

obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
  obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
  obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]

df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.head()

x = obs1_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_2]):
  bot = 0.0
  color = Disease_filtered_combined.uns[obs_2 + '_colors'][0]
  for j in range(i):
    bot += df_obs2.iloc[j]
    color = Disease_filtered_combined.uns[obs_2 + '_colors'][i]
  plt.bar(x, df_obs2.iloc[i], bottom=bot, color=color, label=obs2_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_1 + '_stacked_barplot_color.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.head()

x = obs2_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_1]):
  bot = 0.0
  color = Disease_filtered_combined.uns[obs_1 + '_colors'][0]
  for j in range(i):
    bot += df_obs1.iloc[j]
    color = Disease_filtered_combined.uns[obs_1 + '_colors'][i]
  plt.bar(x, df_obs1.iloc[i], bottom=bot, color=color,
          label=obs1_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_2 + '_stacked_barplot.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

# %%
# get rid of healthy patients
healthy_patient = ["ND001","ND003"]
Disease_filtered_combined = imm_filtered_combined[~imm_filtered_combined.obs['PatientID'].isin(healthy_patient)]
healthy_filtered_combined = imm_filtered_combined[imm_filtered_combined.obs['PatientID'].isin(healthy_patient)]

obs_1 = 'LPorIE'
obs_2 = 'leiden_0.15'

Disease_filtered_combined = Disease_filtered_combined[Disease_filtered_combined.obs['FreshorFrozen']== 'Frozen']

n_categories = {x : len(Disease_filtered_combined.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = Disease_filtered_combined.obs[[obs_2, obs_1]].values

obs2_clusters = Disease_filtered_combined.obs[obs_2].cat.categories.tolist()
obs1_clusters = Disease_filtered_combined.obs[obs_1].cat.categories.tolist()

obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
  obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
  obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]

df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.head()

x = obs1_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_2]):
  bot = 0.0
  color = Disease_filtered_combined.uns[obs_2 + '_colors'][0]
  for j in range(i):
    bot += df_obs2.iloc[j]
    color = Disease_filtered_combined.uns[obs_2 + '_colors'][i]
  plt.bar(x, df_obs2.iloc[i], bottom=bot, color=color, label=obs2_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_1 + '_stacked_barplot_color.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.head()

x = obs2_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_1]):
  bot = 0.0
  color = Disease_filtered_combined.uns[obs_1 + '_colors'][0]
  for j in range(i):
    bot += df_obs1.iloc[j]
    color = Disease_filtered_combined.uns[obs_1 + '_colors'][i]
  plt.bar(x, df_obs1.iloc[i], bottom=bot, color=color,
          label=obs1_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_2 + '_stacked_barplot.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

# %%
# get rid of healthy patients
healthy_patient = ["ND001","ND003"]
Disease_filtered_combined = imm_filtered_combined[~imm_filtered_combined.obs['PatientID'].isin(healthy_patient)]
healthy_filtered_combined = imm_filtered_combined[imm_filtered_combined.obs['PatientID'].isin(healthy_patient)]

obs_1 = 'LPorIE'
obs_2 = 'leiden_0.15'

Disease_filtered_combined = Disease_filtered_combined[Disease_filtered_combined.obs['FreshorFrozen']== 'Fresh']

n_categories = {x : len(Disease_filtered_combined.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = Disease_filtered_combined.obs[[obs_2, obs_1]].values

obs2_clusters = Disease_filtered_combined.obs[obs_2].cat.categories.tolist()
obs1_clusters = Disease_filtered_combined.obs[obs_1].cat.categories.tolist()

obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
  obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
  obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]

df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.head()

x = obs1_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_2]):
  bot = 0.0
  color = Disease_filtered_combined.uns[obs_2 + '_colors'][0]
  for j in range(i):
    bot += df_obs2.iloc[j]
    color = Disease_filtered_combined.uns[obs_2 + '_colors'][i]
  plt.bar(x, df_obs2.iloc[i], bottom=bot, color=color, label=obs2_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_1 + '_stacked_barplot_color.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.head()

x = obs2_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_1]):
  bot = 0.0
  color = Disease_filtered_combined.uns[obs_1 + '_colors'][0]
  for j in range(i):
    bot += df_obs1.iloc[j]
    color = Disease_filtered_combined.uns[obs_1 + '_colors'][i]
  plt.bar(x, df_obs1.iloc[i], bottom=bot, color=color,
          label=obs1_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_2 + '_stacked_barplot.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

# %%
obs_1 = 'LPorIE'
obs_2 = 'leiden_0.15'

n_categories = {x : len(Disease_filtered_combined.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = Disease_filtered_combined.obs[[obs_2, obs_1]].values

obs2_clusters = Disease_filtered_combined.obs[obs_2].cat.categories.tolist()
obs1_clusters = Disease_filtered_combined.obs[obs_1].cat.categories.tolist()

obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
  obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
  obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]

df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.head()

x = obs1_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_2]):
  bot = 0.0
  color = Disease_filtered_combined.uns[obs_2 + '_colors'][0]
  for j in range(i):
    bot += df_obs2.iloc[j]
    color = Disease_filtered_combined.uns[obs_2 + '_colors'][i]
  plt.bar(x, df_obs2.iloc[i], bottom=bot, color=color, label=obs2_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_1 + '_stacked_barplot_color.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.head()

x = obs2_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_1]):
  bot = 0.0
  color = Disease_filtered_combined.uns[obs_1 + '_colors'][0]
  for j in range(i):
    bot += df_obs1.iloc[j]
    color = Disease_filtered_combined.uns[obs_1 + '_colors'][i]
  plt.bar(x, df_obs1.iloc[i], bottom=bot, color=color,
          label=obs1_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_2 + '_stacked_barplot.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

# %% [markdown]
# # Plots of features on UMAP

# %%
obs = 'PatientID'
categories = filtered_combined.obs[obs].cat.categories
for batch in categories:
    sc.pl.umap(filtered_combined, color=obs, groups=[batch])

# %%
obs = 'SampleID'
categories = filtered_combined.obs[obs].cat.categories
for batch in categories:
    sc.pl.umap(filtered_combined, color=obs, groups=[batch])

# %%
obs = 'Tissue_Location'
categories = filtered_combined.obs[obs].cat.categories
for batch in categories:
    sc.pl.umap(filtered_combined, color=obs, groups=[batch])

# %%
obs = 'LPorIE'
categories = filtered_combined.obs[obs].cat.categories
for batch in categories:
    sc.pl.umap(filtered_combined, color=obs, groups=[batch])

# %%
filtered_combined.obs.columns

# %%
obs = 'GVHD_Grade_1'
categories = filtered_combined.obs[obs].cat.categories
for batch in categories:
    sc.pl.umap(filtered_combined, color=obs, groups=[batch])

# %%
obs = 'GVHD_Grade_2'
categories = filtered_combined.obs[obs].cat.categories
for batch in categories:
    sc.pl.umap(filtered_combined, color=obs, groups=[batch])

# %%
obs = 'GVHD_Grade_3'
categories = filtered_combined.obs[obs].cat.categories
for batch in categories:
    sc.pl.umap(filtered_combined, color=obs, groups=[batch])

# %%
# Comparison within IE AND LP

# %%
#Comparison within UPPER AND LOWERE

# %%
# Is there difference between LP and IE
Upper = filtered_combined[filtered_combined.obs['Tissue_Location'] == "Upper GI"]
#savepath = '/Users/lingtingshi/Documents/Azizi_lab/GVHD/'
obs_1 = 'LPorIE'
obs_2 = 'leiden_0.15'

n_categories = {x : len(Upper.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = Upper.obs[[obs_2, obs_1]].values

obs2_clusters = Upper.obs[obs_2].cat.categories.tolist()
obs1_clusters = Upper.obs[obs_1].cat.categories.tolist()

obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
  obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
  obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]

df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.head()

x = obs1_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_2]):
  bot = 0.0
  color = Upper.uns[obs_2 + '_colors'][0]
  for j in range(i):
    bot += df_obs2.iloc[j]
    color = Upper.uns[obs_2 + '_colors'][i]
  plt.bar(x, df_obs2.iloc[i], bottom=bot, color=color, label=obs2_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_1 + '_stacked_barplot_color.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.head()

x = obs2_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_1]):
  bot = 0.0
  color = Upper.uns[obs_1 + '_colors'][0]
  for j in range(i):
    bot += df_obs1.iloc[j]
    color = Upper.uns[obs_1 + '_colors'][i]
  plt.bar(x, df_obs1.iloc[i], bottom=bot, color=color,
          label=obs1_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_2 + '_stacked_barplot.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

# %%
# Is there difference between LP and IE
Lower = filtered_combined[filtered_combined.obs['Tissue_Location'] == "Lower GI"]
#savepath = '/Users/lingtingshi/Documents/Azizi_lab/GVHD/'
obs_1 = 'LPorIE'
obs_2 = 'leiden_0.15'

n_categories = {x : len(Lower.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = Lower.obs[[obs_2, obs_1]].values

obs2_clusters = Lower.obs[obs_2].cat.categories.tolist()
obs1_clusters = Lower.obs[obs_1].cat.categories.tolist()

obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
  obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
  obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]

df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.head()

x = obs1_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_2]):
  bot = 0.0
  color = Lower.uns[obs_2 + '_colors'][0]
  for j in range(i):
    bot += df_obs2.iloc[j]
    color = Lower.uns[obs_2 + '_colors'][i]
  plt.bar(x, df_obs2.iloc[i], bottom=bot, color=color, label=obs2_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_1 + '_stacked_barplot_color.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.head()

x = obs2_clusters
plt.figure(figsize=(6, 6))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_1]):
  bot = 0.0
  color = Lower.uns[obs_1 + '_colors'][0]
  for j in range(i):
    bot += df_obs1.iloc[j]
    color = Lower.uns[obs_1 + '_colors'][i]
  plt.bar(x, df_obs1.iloc[i], bottom=bot, color=color,
          label=obs1_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_2 + '_stacked_barplot.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

# %%
# Is there difference between Upper and Lower
Upper = filtered_combined[filtered_combined.obs['LPorIE'] == "Lamina Propria Cells"]
#savepath = '/Users/lingtingshi/Documents/Azizi_lab/GVHD/'
obs_1 = 'Tissue_Location'
obs_2 = 'leiden_0.15'

n_categories = {x : len(Upper.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = Upper.obs[[obs_2, obs_1]].values

obs2_clusters = Upper.obs[obs_2].cat.categories.tolist()
obs1_clusters = Upper.obs[obs_1].cat.categories.tolist()

obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
  obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
  obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]

df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.head()

x = obs1_clusters
plt.figure(figsize=(3, 3))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_2]):
  bot = 0.0
  color = Upper.uns[obs_2 + '_colors'][0]
  for j in range(i):
    bot += df_obs2.iloc[j]
    color = Upper.uns[obs_2 + '_colors'][i]
  plt.bar(x, df_obs2.iloc[i], bottom=bot, color=color, label=obs2_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_1 + '_stacked_barplot_color.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.head()

x = obs2_clusters
plt.figure(figsize=(3, 3))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_1]):
  bot = 0.0
  color = Upper.uns[obs_1 + '_colors'][0]
  for j in range(i):
    bot += df_obs1.iloc[j]
    color = Upper.uns[obs_1 + '_colors'][i]
  plt.bar(x, df_obs1.iloc[i], bottom=bot, color=color,
          label=obs1_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_2 + '_stacked_barplot.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

# %%
# Is there difference between Upper and Lower
Upper = filtered_combined[filtered_combined.obs['LPorIE'] == "Intraepithelial Cells"]
#savepath = '/Users/lingtingshi/Documents/Azizi_lab/GVHD/'
obs_1 = 'Tissue_Location'
obs_2 = 'leiden_0.15'

n_categories = {x : len(Upper.obs[x].cat.categories) for x in [obs_1, obs_2]}
df = Upper.obs[[obs_2, obs_1]].values

obs2_clusters = Upper.obs[obs_2].cat.categories.tolist()
obs1_clusters = Upper.obs[obs_1].cat.categories.tolist()

obs1_to_obs2 = {k: np.zeros(len(obs2_clusters), dtype="i")
                   for k in obs1_clusters}
obs2_to_obs1 = {k: np.zeros(len(obs1_clusters), dtype="i")
                   for k in obs2_clusters}

for b, l in df:
  obs2_to_obs1[b][obs1_clusters.index(str(l))] += 1
  obs1_to_obs2[l][obs2_clusters.index(str(b))] += 1

obs2_to_obs1_array = np.zeros((len(obs2_clusters), len(obs1_clusters)))
obs1_to_obs2_array = np.zeros((len(obs1_clusters), len(obs2_clusters)))

for i, k in enumerate(obs2_clusters):
  obs2_to_obs1_array[i, :] = deepcopy(obs2_to_obs1[k])
for i, k in enumerate(obs1_clusters):
  obs1_to_obs2_array[i, :] = deepcopy(obs1_to_obs2[k])

sums = np.sum(obs2_to_obs1_array, 0)
for col in range(np.size(obs2_to_obs1_array, 1)):
  for row in range(np.size(obs2_to_obs1_array, 0)):
    obs2_to_obs1_array[row, col] = obs2_to_obs1_array[row, col] / sums[col]

sums2 = np.sum(obs1_to_obs2_array, 0)
for col in range(np.size(obs1_to_obs2_array, 1)):
  for row in range(np.size(obs1_to_obs2_array, 0)):
    obs1_to_obs2_array[row, col] = obs1_to_obs2_array[row, col] / sums2[col]

df_obs2 = pd.DataFrame(obs2_to_obs1_array)
df_obs2.head()

x = obs1_clusters
plt.figure(figsize=(3, 3))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_2]):
  bot = 0.0
  color = Upper.uns[obs_2 + '_colors'][0]
  for j in range(i):
    bot += df_obs2.iloc[j]
    color = Upper.uns[obs_2 + '_colors'][i]
  plt.bar(x, df_obs2.iloc[i], bottom=bot, color=color, label=obs2_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_1 + '_stacked_barplot_color.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

df_obs1 = pd.DataFrame(obs1_to_obs2_array)
df_obs1.head()

x = obs2_clusters
plt.figure(figsize=(3, 3))
plt.xticks(rotation=90)
plt.grid(False)

# stack bars
for i in range(n_categories[obs_1]):
  bot = 0.0
  color = Upper.uns[obs_1 + '_colors'][0]
  for j in range(i):
    bot += df_obs1.iloc[j]
    color = Upper.uns[obs_1 + '_colors'][i]
  plt.bar(x, df_obs1.iloc[i], bottom=bot, color=color,
          label=obs1_clusters[i])
plt.legend(bbox_to_anchor=(1.01, 0.5), loc='center left')
plt.savefig(savepath + '/' + obs_2 + '_stacked_barplot.pdf',
            transparent=True, bbox_inches='tight', pad_inches=0.02)

# %%
Tcells_ann= filtered_combined[filtered_combined.obs['leiden_0.15'].isin(["T_cells"])]

Tcells = '/burg/iicd/users/ls3456/GVHD/adata_file/Tcells_all_f.h5ad'
Tcells_ann.write(Tcells)

# %%
Tcells_ann

# %%
for patient in filtered_combined.obs['PatientID'].unique():
    filtered_combined.obs['color'] = 'Else'
    filtered_combined.obs.loc[filtered_combined.obs['PatientID'].isin([patient]),'color'] = filtered_combined.obs.loc[filtered_combined.obs['PatientID'].isin([patient]),'SampleID']
    meta ='color'
    randomize=np.arange(len(filtered_combined.obs[meta]))
    np.random.shuffle(randomize)
    fig, ax = plt.subplots(figsize=(8,8))
    sns.set_style("whitegrid", {'axes.grid' : False})
    scatter=sns.scatterplot(x=filtered_combined.obsm["X_umap"][:,0][randomize],y=filtered_combined.obsm["X_umap"][:,1][randomize], hue=filtered_combined.obs[meta][randomize],s=3).set(title=patient)
    plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

# %%
meta ='color'
randomize=np.arange(len(filtered_combined.obs[meta]))
np.random.shuffle(randomize)
fig, ax = plt.subplots(figsize=(8,8))
sns.set_style("whitegrid", {'axes.grid' : False})
scatter=sns.scatterplot(x=filtered_combined.obsm["X_umap"][:,0][randomize],y=filtered_combined.obsm["X_umap"][:,1][randomize], hue=filtered_combined.obs[meta][randomize],s=3).set(title=meta)
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

# %%
filtered_combined

# %%
for patient in filtered_combined.obs['PatientID'].unique():
    filtered_combined.obs['color'] = 'Else'
    filtered_combined.obs.loc[filtered_combined.obs['PatientID'].isin([patient]),'color'] = filtered_combined.obs.loc[filtered_combined.obs['PatientID'].isin([patient]),'Days_post-Transplant']
    meta ='color'
    randomize=np.arange(len(filtered_combined.obs[meta]))
    np.random.shuffle(randomize)
    fig, ax = plt.subplots(figsize=(8,8))
    sns.set_style("whitegrid", {'axes.grid' : False})
    scatter=sns.scatterplot(x=filtered_combined.obsm["X_umap"][:,0][randomize],y=filtered_combined.obsm["X_umap"][:,1][randomize], hue=filtered_combined.obs[meta][randomize],s=3).set(title=patient)
    plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

# %%
filtered_combined.obs['leiden_0.15']

# %%
Myleoid = filtered_combined[filtered_combined.obs['leiden_0.15'].isin(["Myeloid"])]

# %%
Myleoid

# %%
Mcells = '/burg/iicd/users/ls3456/GVHD/adata_file/Mcells_all_f.h5ad'
Myleoid.write(Mcells)

# %%
Bcells = filtered_combined[filtered_combined.obs['leiden_0.15']== "B_cells"]

# %%
Bcells

# %%
Bcells_loc = '/burg/iicd/users/ls3456/GVHD/adata_file/Bcells.h5ad'
Bcells.write(Bcells_loc)

# %%
Fcells = filtered_combined[filtered_combined.obs['leiden_0.15']== "Fibroblast"]

# %%
Fcells

# %%
Fcells_loc = '/burg/iicd/users/ls3456/GVHD/adata_file/Fcells.h5ad'
Fcells.write(Fcells_loc)

# %%
table = pd.pivot_table(filtered_combined.obs,index = 'SampleID',aggfunc='count')

# %%
table
